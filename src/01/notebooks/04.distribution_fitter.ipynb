# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 23 17:14:17 2022

@author: zaratejo
"""

from fitter import Fitter ,get_common_distributions, get_distributions

import pandas as pd

# %%
# Load data from statsmodels datasets
path = '/work/Data_OilCompany.csv.xls'
RawData = pd.read_csv(path)

#RawData = pd.read_csv('Data_OilCompany10records.csv')
#RawData = pd.read_csv('PriceHistory.csv')

#data=RawData

#Index(['  Year 1  ', '  Year 2  ', '  Year 3  ', '  Year 4  ', '  Year 5  '], dtype='object')

#Test Year 2
data=RawData.iloc[:,0]
#data=RawData.iloc[:-1,4]
#data=float(data.replace("-",0))

#data=pd.DataFrame(b[:,7])



dist= ['gamma','lognorm', "beta", "burr", "norm"]
dist= ['uniform', "norm"]

dist=get_common_distributions()  #get_distributions()


f = Fitter(data,distributions=dist)

f.fit()

f.summary()
#f.summary(f, Nbest=5, lw=2, plot=True, method="sumsquare_error", clf=True)

print(f.get_best())
# Out:
# 2026-01-30 02:56:00.545 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted cauchy distribution with error=0.0)
# 2026-01-30 02:56:00.583 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted expon distribution with error=0.0)
# 2026-01-30 02:56:00.583 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted chi2 distribution with error=0.0)
# 2026-01-30 02:56:00.688 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted gamma distribution with error=0.0)
# 2026-01-30 02:56:00.710 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted exponpow distribution with error=0.0)
# 2026-01-30 02:56:00.721 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted norm distribution with error=0.0)
# 2026-01-30 02:56:00.768 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted powerlaw distribution with error=0.0)
# 2026-01-30 02:56:00.772 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted lognorm distribution with error=0.0)
# 2026-01-30 02:56:00.775 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted rayleigh distribution with error=0.0)
# 2026-01-30 02:56:00.777 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted uniform distribution with error=0.0)
# {'norm': {'loc': 196593.614, 'scale': 98549.90341700494}}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d1804d27-959b-4770-9ff8-7af629ca870f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
